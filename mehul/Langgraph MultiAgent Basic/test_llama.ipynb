# %%
from dotenv import load_dotenv
from langchain_community.llms.azureml_endpoint import AzureMLOnlineEndpoint, AzureMLEndpointApiType, CustomOpenAIContentFormatter
load_dotenv(override=True)
from langchain_core.messages import HumanMessage

# %%
llm =  AzureMLOnlineEndpoint(
    endpoint_url="https://Meta-Llama-3-1-70B-Instruct-zhlk.westus.models.ai.azure.com/chat/completions",
    endpoint_api_type=AzureMLEndpointApiType.serverless,
    endpoint_api_key="oOGxXLf70uZz1XgcOL1PKzgNBzP4GshV",
    content_formatter=CustomOpenAIContentFormatter(),
)

# %%
res = llm.invoke([HumanMessage(content="What is the capital of France?")])
res
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 res = llm.invoke([HumanMessage(content="What is the capital of France?")])
#       2 res
#
# File ~/AI Projects/Langgraph MultiAgent Basic/langgraph_multiagent/lib/python3.13/site-packages/langchain_core/language_models/llms.py:387, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     376 @override
#     377 def invoke(
#     378     self,
#    (...)    383     **kwargs: Any,
#     384 ) -> str:
#     385     config = ensure_config(config)
#     386     return (
# --> 387         self.generate_prompt(
#     388             [self._convert_input(input)],
#     389             stop=stop,
#     390             callbacks=config.get("callbacks"),
#     391             tags=config.get("tags"),
#     392             metadata=config.get("metadata"),
# ...
